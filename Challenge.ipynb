# %% [markdown]
# # Pertanyaan 1

# %% [markdown]
# Hal pertama yang akan kita lakukan adalah mengimport dua modul. Modul apa yang akan digunakan untuk data structure dan library scientific computing in Python

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Pertanyaan 2

# %% [markdown]
# Langkah kedua, pastikan data Canada.xlsx sudah terdownload. lalu baca data tersebut menggunakan library pertanyaan 1 clue challange read data ini adalah file excel Canada tersebut memiliki 3 tabsheet dan untuk tugas ini kita read tabsheet Canada by Citizenship dan perhatikan isi data pada sheet tersebut, clue selanjutnya pelajari skiprows dan skipfooter

# %%
df = pd.read_excel('Canada.xlsx', sheet_name='Canada by Citizenship', skiprows=20, skipfooter=1)
print(df)
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
# 195  Immigrants  Foreigners         Unknown   999    World   999
#
#              RegName  DEV             DevName   1980  ...  2004  2005  2006  \
# 0      Southern Asia  902  Developing regions     16  ...  2978  3436  3009
# ...

# %% [markdown]
# # Pertanyaan 3

# %% [markdown]
# tampilkan data lima teratas

# %%
df.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %% [markdown]
# # Pertanyaan 4

# %% [markdown]
# tampilkan data lima terbawah

# %%
df.tail()
# Out:
#            Type    Coverage          OdName  AREA AreaName  REG  \
# 191  Immigrants  Foreigners  Western Sahara   903   Africa  912
# 192  Immigrants  Foreigners           Yemen   935     Asia  922
# 193  Immigrants  Foreigners          Zambia   903   Africa  910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa  910
# 195  Immigrants  Foreigners         Unknown   999    World  999
#
#              RegName  DEV             DevName   1980  ...  2004  2005  2006  \
# 191  Northern Africa  902  Developing regions      0  ...     0     0     1
# 192     Western Asia  902  Developing regions      1  ...   124   161   140
# 193   Eastern Africa  902  Developing regions     11  ...    56    91    77
# 194   Eastern Africa  902  Developing regions     72  ...  1450   615   454
# 195            World  999               World  44000  ...  3739  4785  4583
#
#      2007  2008  2009  2010  2011  2012  2013
# 191     0     0     0     0     0     0     0
# ...

# %% [markdown]
# # Pertanyaan 5

# %% [markdown]
# show basic information about your dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 43 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Type      196 non-null    object
#  1   Coverage  196 non-null    object
#  2   OdName    196 non-null    object
#  3   AREA      196 non-null    int64
#  4   AreaName  196 non-null    object
#  5   REG       196 non-null    int64
#  6   RegName   196 non-null    object
#  7   DEV       196 non-null    int64
#  8   DevName   196 non-null    object
#  9   1980      196 non-null    int64
#  10  1981      196 non-null    int64
#  11  1982      196 non-null    int64
#  12  1983      196 non-null    int64
#  13  1984      196 non-null    int64
#  14  1985      196 non-null    int64
#  15  1986      196 non-null    int64
#  16  1987      196 non-null    int64
#  17  1988      196 non-null    int64
#  18  1989      196 non-null    int64
#  19  1990      196 non-null    int64
# ...

# %% [markdown]
# # Pertanyaan 6

# %% [markdown]
# cek missing value, berapakah jumlah missing value?

# %%
df.isnull().sum()
# Out:
# Type        0
# Coverage    0
# OdName      0
# AREA        0
# AreaName    0
# REG         0
# RegName     0
# DEV         0
# DevName     0
# 1980        0
# 1981        0
# 1982        0
# 1983        0
# 1984        0
# 1985        0
# 1986        0
# 1987        0
# 1988        0
# 1989        0
# 1990        0
# 1991        0
# 1992        0
# 1993        0
# 1994        0
# 1995        0
# 1996        0
# 1997        0
# 1998        0
# 1999        0
# 2000        0
# 2001        0
# 2002        0
# 2003        0
# 2004        0
# 2005        0
# 2006        0
# 2007        0
# 2008        0
# 2009        0
# 2010        0
# 2011        0
# 2012        0
# 2013        0
# dtype: int64

# %% [markdown]
# # Pertanyaan 7

# %% [markdown]
# show summary of each column in dataframe

# %%
df.describe()
# Out:
#              AREA          REG         DEV          1980          1981  \
# count  196.000000   196.000000  196.000000    196.000000    196.000000
# mean   913.204082  1247.739796  902.250000    730.290816    656.331633
# std     14.429997  1182.618008    6.959498   3664.971286   2484.869895
# min    903.000000   905.000000  901.000000      0.000000      0.000000
# 25%    903.000000   914.000000  902.000000      0.000000      0.000000
# 50%    908.000000   922.000000  902.000000     13.500000     10.000000
# 75%    935.000000   926.000000  902.000000    263.000000    296.750000
# max    999.000000  5501.000000  999.000000  44000.000000  24796.000000
#
#                1982          1983          1984          1985          1986  \
# count    196.000000    196.000000    196.000000    196.000000    196.000000
# mean     618.239796    455.025510    450.367347    430.336735    506.892857
# std     2198.843498   1529.175952   1580.492649   1469.775915   1529.161726
# ...

# %% [markdown]
# # Pertanyaan 8

# %% [markdown]
# filtering kolom: OdName,1980, 1981, 1982, 1983, 1984, 1985

# %%
df_filter = df[['OdName',1980,1981,1982,1983,1984,1985]]
print(df_filter)
# Out:
#              OdName   1980   1981   1982   1983   1984   1985
# 0       Afghanistan     16     39     39     47     71    340
# 1           Albania      1      0      0      0      0      0
# 2           Algeria     80     67     71     69     63     44
# 3    American Samoa      0      1      0      0      0      0
# 4           Andorra      0      0      0      0      0      0
# ..              ...    ...    ...    ...    ...    ...    ...
# 191  Western Sahara      0      0      0      0      0      0
# 192           Yemen      1      2      1      6      0     18
# 193          Zambia     11     17     11      7     16      9
# 194        Zimbabwe     72    114    102     44     32     29
# 195         Unknown  44000  18078  16904  13635  14855  14368
#
# [196 rows x 7 columns]

# %% [markdown]
# # Pertanyaan 9

# %% [markdown]
# show the data on Asian countries

# %%
df_asian = df[df['AreaName'] == 'Asia']
print(df_asian)
# Out:
#            Type    Coverage                                          OdName  \
# 0    Immigrants  Foreigners                                     Afghanistan
# 8    Immigrants  Foreigners                                         Armenia
# 11   Immigrants  Foreigners                                      Azerbaijan
# 13   Immigrants  Foreigners                                         Bahrain
# 14   Immigrants  Foreigners                                      Bangladesh
# 20   Immigrants  Foreigners                                          Bhutan
# 25   Immigrants  Foreigners                               Brunei Darussalam
# 30   Immigrants  Foreigners                                        Cambodia
# 36   Immigrants  Foreigners                                           China
# 37   Immigrants  Foreigners  China, Hong Kong Special Administrative Region
# 38   Immigrants  Foreigners      China, Macao Special Administrative Region
# ...

# %% [markdown]
# # Pertanyaan 10

# %% [markdown]
# tampilkan data odname = japan dan tahun 1980, 1981, 1982, 1983, 1984, 1985

# %%
df_japan = df[df['OdName'] == 'Japan']
df_japan = df_japan[['OdName',1980,1981,1982,1983,1984,1985]]
print(df_japan)
# Out:
#    OdName  1980  1981  1982  1983  1984  1985
# 87  Japan   701   756   598   309   246   198

# %% [markdown]
# # Pertanyaan 11

# %% [markdown]
# tampilkan histogram pada tahun 2013

# %%
plt.hist(df[2013])
# sns.histplot(df[2013], bins=50)
# df.hist(column=2013)
# Out:
# (array([179.,  11.,   1.,   2.,   0.,   0.,   0.,   0.,   1.,   2.]),
#  array([    0. ,  3412.9,  6825.8, 10238.7, 13651.6, 17064.5, 20477.4,
#         23890.3, 27303.2, 30716.1, 34129. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Pertanyaan 12

# %% [markdown]
# tampilkan line chart df_can['OdName']=='Japan' dan tahun 1980 - 2013

# %%
df_japan = df[df['OdName'] == 'Japan']
years = []
values = []
for year in range(1980, 2014):
    years.append(year)
    values.append(df_japan[year].values[0])
plt.plot(years, values, color='red', marker='o')
plt.title('Japan immigrants in Canada between 1980 and 2013', fontSize=14)
plt.xlabel('Year')
plt.ylabel('Person')
plt.grid(True)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
